# %%
import requests
import json
import pandas as pd
import time

# %%
def OpenAlex_API():
    # each page is 25 records, so I will need to access 20,000 pages
    # I did a sample with 50 pages
    # https://docs.openalex.org/how-to-use-the-api/get-lists-of-entities/paging 
    for i in range(1, 50):
        filename = 'OpenAlex Data Sample Batch' 
        url = 'https://api.openalex.org/works?page=' + str(i) + '&filter=type:types/dataset,authorships.institutions.lineage:i205783295|i2801744472|i170897317|i145311948|i2802508227|i57206974|i130769515|i20089843|i2801919071|i188538660|i79576946|i27837315|i2800403580|i4210130704|i114395901|i169521973|i135310074|i859038795|i204465549'
        r = requests.get(url)
        
        print(r.status_code)
        print(i)
        
        
    with open(filename, 'w', encoding='UTF-8') as fout:
        fout.write(r.text)
        print(i)
    
    time.sleep(3)
    
OpenAlex_API()
# Out:
# 200
# 1
# 200
# 2
# 200
# 3
# 200
# 4
# 200
# 5
# 200
# 6
# 200
# 7
# 200
# 8
# 200
# 9
# 200
# 10
# 200
# 11
# 200
# 12
# 200
# 13
# 200
# 14
# 200
# 15
# 200
# 16
# 200
# 17
# 200
# 18
# 200
# 19
# 200
# 20
# 200
# 21
# 200
# 22
# 200
# 23
# 200
# 24
# 200
# 25
# 200
# 26
# 200
# 27
# 200
# 28
# 200
# 29
# 200
# 30
# 200
# 31
# 200
# 32
# 200
# 33
# 200
# 34
# 200
# 35
# 200
# 36
# 200
# 37
# 200
# 38
# 200
# 39
# 200
# 40
# 200
# 41
# 200
# 42
# 200
# 43
# 200
# 44
# 200
# 45
# 200
# 46
# 200
# 47
# 200
# 48
# 200
# 49
# 49

# %%
def Read_JSON(input, output): 
    with open(input, encoding='UTF-8') as f:
        data = json.loads(f.read())
        df = pd.json_normalize(data, record_path=['results'])
        df.to_csv(output)
        return df

# %%
df = Read_JSON('OpenAlex Data Sample Batch', 'OpenAlex Data Sample Batch.csv')
df = pd.read_csv('OpenAlex Data Sample Batch.csv')
df
# Out:
#     Unnamed: 0                                id  \
# 0            0  https://openalex.org/W2475479478
# 1            1  https://openalex.org/W2502056106
# 2            2  https://openalex.org/W2504304147
# 3            3  https://openalex.org/W2511761712
# 4            4  https://openalex.org/W2523009278
# 5            5  https://openalex.org/W2530275101
# 6            6  https://openalex.org/W2799943535
# 7            7  https://openalex.org/W2950212535
# 8            8  https://openalex.org/W3124054750
# 9            9  https://openalex.org/W3139707217
# 10          10  https://openalex.org/W3146652261
# 11          11  https://openalex.org/W3208865728
# 12          12  https://openalex.org/W3215908698
# 13          13  https://openalex.org/W4205640197
# 14          14  https://openalex.org/W4230224356
# 15          15  https://openalex.org/W4232349622
# 16          16  https://openalex.org/W4234138374
# 17          17  https://openalex.org/W4234409192
# 18          18  https://openalex.org/W4235209664
# 19          19  https://openalex.org/W4235391453
# 20          20  https://openalex.org/W4235890893
# 21          21  https://openalex.org/W4236206676
# 22          22  https://openalex.org/W4239631964
# 23          23  https://openalex.org/W4240332127
# 24          24  https://openalex.org/W4240472019
#
#                                                   doi  \
# 0                https://doi.org/10.17190/amf/1246091
# 1   https://doi.org/10.15484/milc.asqtad.en09a/117...
# 2   https://doi.org/10.15484/milc.asqtad.en09b/117...
# 3   https://doi.org/10.15484/milc.asqtad.en06a/117...
# 4                    https://doi.org/10.18138/1235552
# 5   https://doi.org/10.15484/milc.asqtad.en23b/117...
# 6   https://doi.org/10.15484/milc.asqtad.en15c/117...
# 7      https://doi.org/10.6084/m9.figshare.2082760.v1
# 8         https://doi.org/10.6084/m9.figshare.1604934
# 9                 https://doi.org/10.1257/rct.583-1.0
# 10               https://doi.org/10.1257/rct.1203-1.0
# 11             https://doi.org/10.5281/zenodo.1715175
# 12              https://doi.org/10.5281/zenodo.197100
# 13      https://doi.org/10.3410/f.718219802.793490968
# 14      https://doi.org/10.3410/f.726033159.793518048
# 15      https://doi.org/10.3410/f.723737512.793507544
# 16      https://doi.org/10.3410/f.718312260.793493992
# 17              https://doi.org/10.1515/iupac.69.0563
# 18              https://doi.org/10.1515/iupac.68.4184
# 19      https://doi.org/10.3410/f.718206672.793509011
# 20      https://doi.org/10.3410/f.725233607.793501834
# 21      https://doi.org/10.3410/f.726360754.793518695
# 22              https://doi.org/10.1515/iupac.83.0502
# 23              https://doi.org/10.1515/iupac.85.0149
# 24              https://doi.org/10.1515/iupac.76.0516
#
#                                                 title  \
# 0               AmeriFlux AmeriFlux US-Pon Ponca City
# 1   Lattice QCD gauge ensemble: USQCD/MILC/asqtad/...
# 2   Lattice QCD gauge ensemble: USQCD/MILC/asqtad/...
# 3   Lattice QCD gauge ensemble: USQCD/MILC/asqtad/...
# 4   Public Data Set: Impedance of an Intense Plasm...
# 5   Lattice QCD gauge ensemble: USQCD/MILC/asqtad/...
# 6   Lattice QCD gauge ensemble: USQCD/MILC/asqtad/...
# 7   Cluster-Robust Bootstrap Inference in Quantile...
# 8   Inference in High-Dimensional Panel Models Wit...
# 9                 Menstruation and Education in Nepal
# 10  Can employment reduce lawlessness and rebellio...
# 11                                 MedleyDB 2.0 Audio
# 12            Training Material For Chip-Seq Analysis
# 13  Faculty Opinions recommendation of Psoriasis i...
# 14  Faculty Opinions recommendation of Small airwa...
# 15  Faculty Opinions recommendation of Green tea e...
# 16  Faculty Opinions recommendation of Bevacizumab...
# 17  Critical Survey of Stability Constants of Comp...
# 18  Preservation and Utilization of Natural Biodiv...
# 19  Faculty Opinions recommendation of Diet rapidl...
# 20  Faculty Opinions recommendation of Reagent and...
# 21  Faculty Opinions recommendation of Effect of e...
# 22                Hydrogen Bonding: A Critical Survey
# 23                         Stimuli-Responsive Polymer
# 24                            Open Photoacoustic Cell
#
#                                          display_name  publication_year  \
# 0               AmeriFlux AmeriFlux US-Pon Ponca City              2016
# 1   Lattice QCD gauge ensemble: USQCD/MILC/asqtad/...              2015
# 2   Lattice QCD gauge ensemble: USQCD/MILC/asqtad/...              2015
# 3   Lattice QCD gauge ensemble: USQCD/MILC/asqtad/...              2015
# 4   Public Data Set: Impedance of an Intense Plasm...              2016
# 5   Lattice QCD gauge ensemble: USQCD/MILC/asqtad/...              2015
# 6   Lattice QCD gauge ensemble: USQCD/MILC/asqtad/...              2015
# 7   Cluster-Robust Bootstrap Inference in Quantile...              2016
# 8   Inference in High-Dimensional Panel Models Wit...              2016
# 9                 Menstruation and Education in Nepal              2015
# 10  Can employment reduce lawlessness and rebellio...              2016
# 11                                 MedleyDB 2.0 Audio              2016
# 12            Training Material For Chip-Seq Analysis              2016
# 13  Faculty Opinions recommendation of Psoriasis i...              2014
# 14  Faculty Opinions recommendation of Small airwa...              2016
# 15  Faculty Opinions recommendation of Green tea e...              2015
# 16  Faculty Opinions recommendation of Bevacizumab...              2014
# 17  Critical Survey of Stability Constants of Comp...              2016
# 18  Preservation and Utilization of Natural Biodiv...              2016
# 19  Faculty Opinions recommendation of Diet rapidl...              2015
# 20  Faculty Opinions recommendation of Reagent and...              2014
# 21  Faculty Opinions recommendation of Effect of e...              2016
# 22                Hydrogen Bonding: A Critical Survey              2016
# 23                         Stimuli-Responsive Polymer              2016
# 24                            Open Photoacoustic Cell              2016
#
#    publication_date language     type type_crossref  ...  \
# 0        2016-01-01       en  dataset       dataset  ...
# 1        2015-01-01       fr  dataset       dataset  ...
# 2        2015-01-01      NaN  dataset       dataset  ...
# 3        2015-01-01       fr  dataset       dataset  ...
# 4        2016-05-31       en  dataset       dataset  ...
# 5        2015-01-01      NaN  dataset       dataset  ...
# 6        2015-01-01       fr  dataset       dataset  ...
# 7        2016-01-01       en  dataset       dataset  ...
# 8        2016-01-01       en  dataset       dataset  ...
# 9        2015-01-28       en  dataset       dataset  ...
# 10       2016-04-27       en  dataset       dataset  ...
# 11       2016-08-11       en  dataset       dataset  ...
# 12       2016-12-08       en  dataset       dataset  ...
# 13       2014-02-17       en  dataset       dataset  ...
# 14       2016-05-10       en  dataset       dataset  ...
# 15       2015-06-19       en  dataset       dataset  ...
# 16       2014-04-22       en  dataset       dataset  ...
# 17       2016-02-29       en  dataset       dataset  ...
# 18       2016-02-28       en  dataset       dataset  ...
# 19       2015-08-18       en  dataset       dataset  ...
# 20       2014-11-26       en  dataset       dataset  ...
# 21       2016-05-23       en  dataset       dataset  ...
# 22       2016-03-13       en  dataset       dataset  ...
# 23       2016-03-15       en  dataset       dataset  ...
# 24       2016-03-14       en  dataset       dataset  ...
#
#    abstract_inverted_index.lens, abstract_inverted_index.photoacoustic  \
# 0                            NaN                                   NaN
# 1                            NaN                                   NaN
# 2                            NaN                                   NaN
# 3                            NaN                                   NaN
# 4                            NaN                                   NaN
# 5                            NaN                                   NaN
# 6                            NaN                                   NaN
# 7                            NaN                                   NaN
# 8                            NaN                                   NaN
# 9                            NaN                                   NaN
# 10                           NaN                                   NaN
# 11                           NaN                                   NaN
# 12                           NaN                                   NaN
# 13                           NaN                                   NaN
# 14                           NaN                                   NaN
# 15                           NaN                                   NaN
# 16                           NaN                                   NaN
# 17                           NaN                                   NaN
# 18                           NaN                                   NaN
# 19                           NaN                                   NaN
# 20                           NaN                                   NaN
# 21                           NaN                                   NaN
# 22                           NaN                                   NaN
# 23                           NaN                                   NaN
# 24                          [67]                                  [68]
#
#    abstract_inverted_index.spectroscopy,  abstract_inverted_index.radiometry,  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                    NaN                                  NaN
# 5                                    NaN                                  NaN
# 6                                    NaN                                  NaN
# 7                                    NaN                                  NaN
# 8                                    NaN                                  NaN
# 9                                    NaN                                  NaN
# 10                                   NaN                                  NaN
# 11                                   NaN                                  NaN
# 12                                   NaN                                  NaN
# 13                                   NaN                                  NaN
# 14                                   NaN                                  NaN
# 15                                   NaN                                  NaN
# 16                                   NaN                                  NaN
# 17                                   NaN                                  NaN
# 18                                   NaN                                  NaN
# 19                                   NaN                                  NaN
# 20                                   NaN                                  NaN
# 21                                   NaN                                  NaN
# 22                                   NaN                                  NaN
# 23                                   NaN                                  NaN
# 24                                  [69]                                 [71]
#
#     abstract_inverted_index.calorimetry,  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                                   NaN
# 11                                   NaN
# 12                                   NaN
# 13                                   NaN
# 14                                   NaN
# 15                                   NaN
# 16                                   NaN
# 17                                   NaN
# 18                                   NaN
# 19                                   NaN
# 20                                   NaN
# 21                                   NaN
# 22                                   NaN
# 23                                   NaN
# 24                                  [72]
#
#    abstract_inverted_index.interferometry,  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22                                     NaN
# 23                                     NaN
# 24                                    [73]
#
#    abstract_inverted_index.deflection,  abstract_inverted_index.reflection,  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
# 5                                  NaN                                  NaN
# 6                                  NaN                                  NaN
# 7                                  NaN                                  NaN
# 8                                  NaN                                  NaN
# 9                                  NaN                                  NaN
# 10                                 NaN                                  NaN
# 11                                 NaN                                  NaN
# 12                                 NaN                                  NaN
# 13                                 NaN                                  NaN
# 14                                 NaN                                  NaN
# 15                                 NaN                                  NaN
# 16                                 NaN                                  NaN
# 17                                 NaN                                  NaN
# 18                                 NaN                                  NaN
# 19                                 NaN                                  NaN
# 20                                 NaN                                  NaN
# 21                                 NaN                                  NaN
# 22                                 NaN                                  NaN
# 23                                 NaN                                  NaN
# 24                                [74]                                 [75]
#
#     abstract_inverted_index.spectroscopies,  abstract_inverted_index.effects.
# 0                                       NaN                               NaN
# 1                                       NaN                               NaN
# 2                                       NaN                               NaN
# 3                                       NaN                               NaN
# 4                                       NaN                               NaN
# 5                                       NaN                               NaN
# 6                                       NaN                               NaN
# 7                                       NaN                               NaN
# 8                                       NaN                               NaN
# 9                                       NaN                               NaN
# 10                                      NaN                               NaN
# 11                                      NaN                               NaN
# 12                                      NaN                               NaN
# 13                                      NaN                               NaN
# 14                                      NaN                               NaN
# 15                                      NaN                               NaN
# 16                                      NaN                               NaN
# 17                                      NaN                               NaN
# 18                                      NaN                               NaN
# 19                                      NaN                               NaN
# 20                                      NaN                               NaN
# 21                                      NaN                               NaN
# 22                                      NaN                               NaN
# 23                                      NaN                               NaN
# 24                                     [79]                              [87]
#
# [25 rows x 959 columns]

# %%
import requests
import time
import json

def fetch_records(url, params=None, headers=None):
    """Fetch records from OpenAlex API."""
    response = requests.get(url, headers=headers)
    response.raise_for_status()  # Raise an error for bad responses
    return response.json()

def OpenAlex_API2():
    url = 'https://api.openalex.org/works?page=1&filter=type:types/dataset,authorships.institutions.lineage:i205783295|i2801744472|i170897317|i145311948|i2802508227|i57206974|i130769515|i20089843|i2801919071|i188538660|i79576946|i27837315|i2800403580|i4210130704|i114395901|i169521973|i135310074|i859038795|i204465549'
    headers = {
                'Content-Type': 'application/json'    
                }
    params = {
        "page_size": 10,
        }
    
    while True:
        filename = 'Open Alex Data Batch 2'
        data = fetch_records(url, params)
        works = data.get("results", [])
        
        for work in works:
            print(f"Title: {work.get('title', 'No Title')}")
            print(f"DOI: {work.get('doi', 'No DOI')}")
            print(f"Published Date: {work.get('publication_date', 'No Date')}")
            print("-" * 40) 
        print(len(work))
 
    
        next_cursor = data.get("meta", {}).get("next_cursor")
        print(next_cursor)
        with open(filename, 'w', encoding='UTF-8') as fout:
            fout.write(json.dumps(data))
        if not next_cursor:
            break
         
        params["cursor"] = next_cursor
        time.sleep(3)

OpenAlex_API2()

# %%
df = Read_JSON('Open Alex Data Batch 2', 'OpenAlex Data Batch 2.csv')
df = pd.read_csv('OpenAlex Data Batch 2.csv')
df

# %%
import requests
import time
import json
# First attempt using ChatGPT
def fetch_openalex_data(url):
    page = 1
    while True:
        filename = 'Open Alex Data Batch 3'

        # Construct the full URL with the current page number
        current_url = f"{url}&page={page}&per-page=200"
        print(f"Fetching data from: {current_url}")
        
        # Send the GET request to the API
        response = requests.get(current_url)
        
        # Check for request success
        if response.status_code == 200:
            print(f"Status code: {response.status_code}", ';',  "Page number: ", page)
        if response.status_code != 200:
            print(f"Failed to fetch data: {response.status_code}")
            break
        
        # Parse the JSON response
        data = response.json()
        with open(filename, 'w', encoding='UTF-8') as fout:
                fout.write(json.dumps(data))    
        # Check if there are any works in the response
        if 'results' not in data or len(data['results']) == 0:
            print("No more results to fetch.")
            break
        record_number = 0
        for work in data['results']:
            #with open(filename, 'w', encoding='UTF-8') as fout:
                #fout.write(json.dumps(work))
            record_number += 1
            print("Page number: ", page, record_number, work)
            
    
        
        # Move to the next page
        page += 1
        
        
        time.sleep(3)


if __name__ == "__main__":
    #base_url = "https://api.openalex.org/works?filter=type:types/dataset,authorships.institutions.lineage:i205783295|i2801744472|i170897317|i145311948|i2802508227|i57206974|i130769515|i20089843|i2801919071|i188538660|i79576946|i27837315|i2800403580|i4210130704|i114395901|i169521973|i135310074|i859038795|i204465549"
    base_url = "https://api.openalex.org/works?filter=type:types/dataset,authorships.institutions.lineage:i205783295"
    fetch_openalex_data(base_url)

# %%
df = Read_JSON('Open Alex Data Batch 3', 'Open Alex Data Batch 3.csv')
df = pd.read_csv('OpenAlex Data Batch 3.csv')

df
# loses results heirarchy
