# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('2026-04-22-UMN-Source.csv', index_col=0)

# %%
pd.set_option("display.max_columns", 55)

# %%
df.columns
# Out:
# Index(['id', 'doi', 'type', 'institutions-type', 'title', 'publication_year',
#        'publication_date', 'language', 'authorships-author-author_id',
#        'authorships-author-display_name', 'author_position', 'orcid',
#        'primary_topic-id', 'primary_topic-display_name', 'primary_topic-score',
#        'primary_topic-subfield', 'primary_topic-field', 'primary_topic-domain',
#        'topics-id', 'topics-display_name', 'topics-subfield-id',
#        'topics-subfield-display_name', 'topics-field-id',
#        'topics-field-display_name', 'topics-domain-id',
#        'topics-domain-display_name', 'apc_list', 'apc_paid', 'fwci',
#        'has_fulltext', 'cited_by_count', 'volume', 'issue', 'first_page',
#        'last_page', 'index location', 'primary_location-source-display_name',
#        'retracted', 'is_oa', 'oa_status', 'license', 'institutions-id',
#        'institutions-display_name', 'raw_affiliation_strings', 'country_code',
#        'ror', 'lineage'],
#       dtype='object')

# %%
df.head()
# Out:
#                                  id                                 doi  \
# 0  https://openalex.org/W3081810959  https://doi.org/10.13020/3eks-j059
# 1  https://openalex.org/W3081810959  https://doi.org/10.13020/3eks-j059
# 2  https://openalex.org/W3081810959  https://doi.org/10.13020/3eks-j059
# 3  https://openalex.org/W3081810959  https://doi.org/10.13020/3eks-j059
# 4  https://openalex.org/W3081810959  https://doi.org/10.13020/3eks-j059
#
#       type institutions-type  \
# 0  dataset               NaN
# 1  dataset               NaN
# 2  dataset               NaN
# 3  dataset               NaN
# 4  dataset               NaN
#
#                                                title  publication_year  \
# 0  Minnesota Solvation Database (MNSOL) version 2012              1998
# 1  Minnesota Solvation Database (MNSOL) version 2012              1998
# 2  Minnesota Solvation Database (MNSOL) version 2012              1998
# 3  Minnesota Solvation Database (MNSOL) version 2012              1998
# 4  Minnesota Solvation Database (MNSOL) version 2012              1998
#
#   publication_date language      authorships-author-author_id  \
# 0       1998-01-01       en  https://openalex.org/A5061017744
# 1       1998-01-01       en  https://openalex.org/A5053083096
# 2       1998-01-01       en  https://openalex.org/A5111863630
# 3       1998-01-01       en  https://openalex.org/A5113505750
# 4       1998-01-01       en                               NaN
#
#   authorships-author-display_name author_position  \
# 0           Aleksandr V. Marenich           first
# 1                  Casey P. Kelly          middle
# 2               Jason D. Thompson          middle
# 3              Gregory D. Hawkins          middle
# 4               Chambers, Candy C          middle
#
#                                    orcid             primary_topic-id  \
# 0  https://orcid.org/0000-0003-0288-843X  https://openalex.org/T12157
# 1                                    NaN  https://openalex.org/T12157
# 2  https://orcid.org/0009-0002-4710-8505  https://openalex.org/T12157
# 3                                    NaN  https://openalex.org/T12157
# 4                                    NaN  https://openalex.org/T12157
#
#           primary_topic-display_name  primary_topic-score  \
# 0  Geochemistry and Geologic Mapping               0.6013
# 1  Geochemistry and Geologic Mapping               0.6013
# 2  Geochemistry and Geologic Mapping               0.6013
# 3  Geochemistry and Geologic Mapping               0.6013
# 4  Geochemistry and Geologic Mapping               0.6013
#
#                 primary_topic-subfield             primary_topic-field  \
# 0  https://openalex.org/subfields/1702  https://openalex.org/fields/17
# 1  https://openalex.org/subfields/1702  https://openalex.org/fields/17
# 2  https://openalex.org/subfields/1702  https://openalex.org/fields/17
# 3  https://openalex.org/subfields/1702  https://openalex.org/fields/17
# 4  https://openalex.org/subfields/1702  https://openalex.org/fields/17
#
#              primary_topic-domain                    topics-id  \
# 0  https://openalex.org/domains/3  https://openalex.org/T12157
# 1  https://openalex.org/domains/3  https://openalex.org/T12157
# 2  https://openalex.org/domains/3  https://openalex.org/T12157
# 3  https://openalex.org/domains/3  https://openalex.org/T12157
# 4  https://openalex.org/domains/3  https://openalex.org/T12157
#
#                  topics-display_name                   topics-subfield-id  \
# 0  Geochemistry and Geologic Mapping  https://openalex.org/subfields/1702
# 1  Geochemistry and Geologic Mapping  https://openalex.org/subfields/1702
# 2  Geochemistry and Geologic Mapping  https://openalex.org/subfields/1702
# 3  Geochemistry and Geologic Mapping  https://openalex.org/subfields/1702
# 4  Geochemistry and Geologic Mapping  https://openalex.org/subfields/1702
#
#   topics-subfield-display_name                 topics-field-id  \
# 0      Artificial Intelligence  https://openalex.org/fields/17
# 1      Artificial Intelligence  https://openalex.org/fields/17
# 2      Artificial Intelligence  https://openalex.org/fields/17
# 3      Artificial Intelligence  https://openalex.org/fields/17
# 4      Artificial Intelligence  https://openalex.org/fields/17
#
#   topics-field-display_name                topics-domain-id  \
# 0          Computer Science  https://openalex.org/domains/3
# 1          Computer Science  https://openalex.org/domains/3
# 2          Computer Science  https://openalex.org/domains/3
# 3          Computer Science  https://openalex.org/domains/3
# 4          Computer Science  https://openalex.org/domains/3
#
#   topics-domain-display_name  apc_list  apc_paid  fwci  has_fulltext  \
# 0          Physical Sciences       NaN       NaN   NaN         False
# 1          Physical Sciences       NaN       NaN   NaN         False
# 2          Physical Sciences       NaN       NaN   NaN         False
# 3          Physical Sciences       NaN       NaN   NaN         False
# 4          Physical Sciences       NaN       NaN   NaN         False
#
#    cited_by_count  volume  issue  first_page  last_page index location  \
# 0              41     NaN    NaN         NaN        NaN       datacite
# 1              41     NaN    NaN         NaN        NaN       datacite
# 2              41     NaN    NaN         NaN        NaN       datacite
# 3              41     NaN    NaN         NaN        NaN       datacite
# 4              41     NaN    NaN         NaN        NaN       datacite
#
#                 primary_location-source-display_name  retracted  \
# 0  University of Minnesota Digital Conservancy (U...      False
# 1  University of Minnesota Digital Conservancy (U...      False
# 2  University of Minnesota Digital Conservancy (U...      False
# 3  University of Minnesota Digital Conservancy (U...      False
# 4  University of Minnesota Digital Conservancy (U...      False
#
#   index location.1             primary_location-source-display_name.1  is_oa  \
# 0         datacite  University of Minnesota Digital Conservancy (U...   True
# 1         datacite  University of Minnesota Digital Conservancy (U...   True
# 2         datacite  University of Minnesota Digital Conservancy (U...   True
# 3         datacite  University of Minnesota Digital Conservancy (U...   True
# 4         datacite  University of Minnesota Digital Conservancy (U...   True
#
#   oa_status      license institutions-id institutions-display_name  \
# 0     green  cc-by-nc-nd             NaN                       NaN
# 1     green  cc-by-nc-nd             NaN                       NaN
# 2     green  cc-by-nc-nd             NaN                       NaN
# 3     green  cc-by-nc-nd             NaN                       NaN
# 4     green  cc-by-nc-nd             NaN                       NaN
#
#   raw_affiliation_strings country_code  ror lineage
# 0                     NaN          NaN  NaN     NaN
# 1                     NaN          NaN  NaN     NaN
# 2                     NaN          NaN  NaN     NaN
# 3                     NaN          NaN  NaN     NaN
# 4                     NaN          NaN  NaN     NaN

# %%
def Matching_columns(df, col1, col2):
    match = df[col1].equals(df[col2])
    return match

# %%
# primary topic
Matching_columns(df, 'primary_topic-display_name', 'topics-display_name')
# Out:
# True

# %%
# subfield
Matching_columns(df, 'primary_topic-subfield', 'topics-subfield-id')
# Out:
# True

# %%
# field
Matching_columns(df, 'primary_topic-field', 'topics-field-id')
# Out:
# True

# %%
# domain
Matching_columns(df, 'primary_topic-domain', 'topics-domain-id')
# Out:
# True

# %%
len(df['topics-display_name'])

# %%
df['ror'].isna().sum(), df['orcid'].isna().sum()

# %%
(df['ror'].isna() & df['orcid'].isna()).sum()

# %%
df['ror'].isna().groupby(df['publication_year']).sum().reset_index().sort_values(by=['ror'], ascending=False).reset_index(drop=True)

# %%
topics_display_name_ror = df['ror'].isna().groupby(df['topics-display_name']).sum().reset_index().sort_values(by=['ror'], ascending=False)
topics_display_name_ror.head(15).reset_index(drop=True)

# %%
topics_subfield_display_name_ror = df['ror'].isna().groupby(df['topics-subfield-display_name']).sum().reset_index().sort_values(by=['ror'], ascending=False)
topics_subfield_display_name_ror.head(15).reset_index(drop=True)

# %%
topics_field_display_name_ror = df['ror'].isna().groupby(df['topics-field-display_name']).sum().reset_index().sort_values(by=['ror'], ascending=False)
topics_field_display_name_ror.head(15).reset_index(drop=True)
